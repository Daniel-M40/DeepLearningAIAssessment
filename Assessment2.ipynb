# %%
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import os
from torch.optim.lr_scheduler import OneCycleLR

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# %%
# Load Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
def detect_face(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(faces) == 0:
        return None  # No face detected

    x, y, w, h = faces[0]
    face = image[y:y+h, x:x+w]
    face = cv2.resize(face, (224, 224))
    return face

# %%
# Define dataset paths
train_dir = 'CK_dataset/train'
test_dir = 'CK_dataset/test'

train_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1)),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load dataset with updated transforms
train_dataset = ImageFolder(train_dir, transform=train_transform)
test_dataset = ImageFolder(test_dir, transform=test_transform)

# Dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR, ReduceLROnPlateau

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define DataLoaders
batch_size = 128

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# Modify Fully Connected Layer for 6 Classes & Add Dropout
num_features = model.fc.in_features


# Dropout to prevent overfitting
model.fc = nn.Sequential(
    nn.Dropout(p=0.5),
    nn.Linear(num_features, 6)
)

# Initialise weights
nn.init.kaiming_normal_(model.fc[1].weight)

# Move model to GPU/CPU
model.to(device)

# Compute Class Weights
class_counts = torch.tensor([18, 7, 30, 36, 17, 35]) 
class_weights = 1.0 / class_counts
class_weights = class_weights / class_weights.sum()  # Normalise
class_weights = class_weights.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights, label_smoothing=0.1)
    
optimizer = optim.AdamW(model.parameters(), lr=2e-4, weight_decay=1e-4)

scheduler = OneCycleLR(
    optimizer,
    max_lr=2e-3,
    total_steps=50 * len(train_loader),
    pct_start=0.3,
    anneal_strategy="cos",
    div_factor=10, 
    final_div_factor=100
)


plateau_scheduler = ReduceLROnPlateau(
    optimizer,
    mode="min",
    patience=4,  # Reduce LR if no improvement for 4 epochs
    factor=0.5,  # Reduce LR by 50%
    min_lr=1e-6
)


# Mixed Precision Training
scaler = torch.cuda.amp.GradScaler() if torch.cuda.is_available() else None

# %%
num_epochs = 50
train_acc_list, test_acc_list, train_loss_list, test_loss_list = [], [], [], []

best_test_acc = 0.0  # Track the best model accuracy

for epoch in range(num_epochs):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():  # Enable mixed precision
            outputs = model(images)
            loss = criterion(outputs, labels)

        # If mixed precision is available, use GradScaler
        if scaler:
            scaler.scale(loss).backward()

            # Unscale gradients and clip them
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            scaler.step(optimizer)
            scaler.update()
        else:
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
            optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

        # Step OneCycleLR **per batch**, not per epoch
        if isinstance(scheduler, torch.optim.lr_scheduler.OneCycleLR):
            scheduler.step()

    train_accuracy = 100 * correct / total
    train_acc_list.append(train_accuracy)
    train_loss_list.append(running_loss / len(train_loader))

    # %% Evaluation Phase
    model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            with torch.cuda.amp.autocast():
                outputs = model(images)
                loss = criterion(outputs, labels)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_accuracy = 100 * correct_test / total_test
    test_acc_list.append(test_accuracy)
    test_loss_list.append(test_loss / len(test_loader))

    # Reduce Learning Rate (only if using ReduceLROnPlateau)
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(test_loss_list[-1])  # Adjust LR if plateau detected

    # Save best model based on test accuracy
    if test_accuracy > best_test_acc:
        best_test_acc = test_accuracy
        torch.save(model.state_dict(), "best_emotion_recognition_model.pth")

    # Logging
    print(f"Epoch [{epoch + 1}/{num_epochs}], LR: {optimizer.param_groups[0]['lr']:.8f}, "
          f"Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_accuracy:.2f}%, "
          f"Test Loss: {test_loss_list[-1]:.4f}, Test Acc: {test_accuracy:.2f}%")

print("Training complete. Best Model Saved.")
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7280\3207898019.py:14: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():  # Enable mixed precision
# C:\Users\untitled1\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# C:\Users\danie\AppData\Local\Temp\ipykernel_7280\3207898019.py:54: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch [1/50], LR: 0.00021991, Train Loss: 2.6202, Train Acc: 27.57%, Test Loss: 1.9739, Test Acc: 37.76%
# Epoch [2/50], LR: 0.00027875, Train Loss: 2.1252, Train Acc: 43.40%, Test Loss: 1.9892, Test Acc: 41.96%
# Epoch [3/50], LR: 0.00037392, Train Loss: 1.9741, Train Acc: 46.63%, Test Loss: 1.8764, Test Acc: 53.15%
# Epoch [4/50], LR: 0.00050121, Train Loss: 1.8795, Train Acc: 52.49%, Test Loss: 1.9787, Test Acc: 48.95%
# Epoch [5/50], LR: 0.00065499, Train Loss: 1.8824, Train Acc: 52.79%, Test Loss: 2.2446, Test Acc: 32.17%
# Epoch [6/50], LR: 0.00082845, Train Loss: 1.8180, Train Acc: 53.08%, Test Loss: 4.9277, Test Acc: 43.36%
# Epoch [7/50], LR: 0.00101393, Train Loss: 1.7481, Train Acc: 49.85%, Test Loss: 2.8726, Test Acc: 56.64%
# Epoch [8/50], LR: 0.00120322, Train Loss: 1.6539, Train Acc: 51.03%, Test Loss: 2.2491, Test Acc: 37.76%
# Epoch [9/50], LR: 0.00138793, Train Loss: 1.6081, Train Acc: 52.49%, Test Loss: 2.1025, Test Acc: 44.06%
# Epoch [10/50], LR: 0.00155992, Train Loss: 1.6361, Train Acc: 53.37%, Test Loss: 1.6476, Test Acc: 48.25%
# Epoch [11/50], LR: 0.00171155, Train Loss: 1.5112, Train Acc: 56.60%, Test Loss: 1.8180, Test Acc: 52.45%
# Epoch [12/50], LR: 0.00183614, Train Loss: 1.5099, Train Acc: 53.08%, Test Loss: 3.4610, Test Acc: 33.57%
# Epoch [13/50], LR: 0.00192815, Train Loss: 1.5307, Train Acc: 50.15%, Test Loss: 1.8668, Test Acc: 40.56%
# Epoch [14/50], LR: 0.00198354, Train Loss: 1.5041, Train Acc: 56.01%, Test Loss: 1.6785, Test Acc: 49.65%
# Epoch [15/50], LR: 0.00199997, Train Loss: 1.4473, Train Acc: 60.70%, Test Loss: 1.9905, Test Acc: 51.05%
# Epoch [16/50], LR: 0.00199521, Train Loss: 1.4019, Train Acc: 58.94%, Test Loss: 3.0879, Test Acc: 30.07%
# Epoch [17/50], LR: 0.00198246, Train Loss: 1.3227, Train Acc: 63.05%, Test Loss: 1.7066, Test Acc: 61.54%
# Epoch [18/50], LR: 0.00196180, Train Loss: 1.4628, Train Acc: 59.53%, Test Loss: 1.6174, Test Acc: 46.15%
# Epoch [19/50], LR: 0.00193340, Train Loss: 1.3352, Train Acc: 63.34%, Test Loss: 1.8510, Test Acc: 41.96%
# Epoch [20/50], LR: 0.00189750, Train Loss: 1.3553, Train Acc: 60.12%, Test Loss: 1.5500, Test Acc: 55.94%
# Epoch [21/50], LR: 0.00185438, Train Loss: 1.3874, Train Acc: 58.65%, Test Loss: 1.6942, Test Acc: 55.94%
# Epoch [22/50], LR: 0.00180439, Train Loss: 1.3259, Train Acc: 64.52%, Test Loss: 1.6255, Test Acc: 49.65%
# Epoch [23/50], LR: 0.00174793, Train Loss: 1.2279, Train Acc: 69.50%, Test Loss: 1.3551, Test Acc: 58.04%
# Epoch [24/50], LR: 0.00168546, Train Loss: 1.2300, Train Acc: 68.91%, Test Loss: 1.5598, Test Acc: 67.83%
# Epoch [25/50], LR: 0.00161747, Train Loss: 1.2575, Train Acc: 64.22%, Test Loss: 1.5941, Test Acc: 60.84%
# Epoch [26/50], LR: 0.00154452, Train Loss: 1.2456, Train Acc: 73.90%, Test Loss: 1.4041, Test Acc: 64.34%
# Epoch [27/50], LR: 0.00146720, Train Loss: 1.0821, Train Acc: 74.19%, Test Loss: 1.6396, Test Acc: 55.24%
# Epoch [28/50], LR: 0.00138612, Train Loss: 1.2102, Train Acc: 68.91%, Test Loss: 1.3887, Test Acc: 64.34%
# Epoch [29/50], LR: 0.00130194, Train Loss: 1.1425, Train Acc: 69.21%, Test Loss: 1.3858, Test Acc: 60.84%
# Epoch [30/50], LR: 0.00121534, Train Loss: 1.0777, Train Acc: 75.37%, Test Loss: 1.3946, Test Acc: 65.03%
# Epoch [31/50], LR: 0.00112702, Train Loss: 1.0949, Train Acc: 78.01%, Test Loss: 1.4678, Test Acc: 62.24%
# Epoch [32/50], LR: 0.00103767, Train Loss: 1.1180, Train Acc: 75.95%, Test Loss: 1.4088, Test Acc: 65.73%
# Epoch [33/50], LR: 0.00094804, Train Loss: 1.0599, Train Acc: 75.95%, Test Loss: 1.4720, Test Acc: 58.04%
# Epoch [34/50], LR: 0.00085883, Train Loss: 1.0298, Train Acc: 80.06%, Test Loss: 1.4294, Test Acc: 66.43%
# Epoch [35/50], LR: 0.00077076, Train Loss: 1.0310, Train Acc: 79.47%, Test Loss: 1.3954, Test Acc: 67.83%
# Epoch [36/50], LR: 0.00068455, Train Loss: 0.9869, Train Acc: 78.01%, Test Loss: 1.3466, Test Acc: 67.83%
# Epoch [37/50], LR: 0.00060089, Train Loss: 0.9716, Train Acc: 81.82%, Test Loss: 1.5629, Test Acc: 59.44%
# Epoch [38/50], LR: 0.00052044, Train Loss: 0.9152, Train Acc: 84.16%, Test Loss: 1.4298, Test Acc: 67.13%
# Epoch [39/50], LR: 0.00044387, Train Loss: 0.9557, Train Acc: 81.82%, Test Loss: 1.3732, Test Acc: 65.03%
# Epoch [40/50], LR: 0.00037178, Train Loss: 0.9100, Train Acc: 83.87%, Test Loss: 1.4038, Test Acc: 70.63%
# Epoch [41/50], LR: 0.00030476, Train Loss: 0.8566, Train Acc: 86.80%, Test Loss: 1.3905, Test Acc: 67.83%
# Epoch [42/50], LR: 0.00024334, Train Loss: 0.8356, Train Acc: 87.98%, Test Loss: 1.4315, Test Acc: 68.53%
# Epoch [43/50], LR: 0.00018803, Train Loss: 0.8570, Train Acc: 86.51%, Test Loss: 1.4213, Test Acc: 69.93%
# Epoch [44/50], LR: 0.00013926, Train Loss: 0.8109, Train Acc: 86.51%, Test Loss: 1.3910, Test Acc: 67.13%
# Epoch [45/50], LR: 0.00009743, Train Loss: 0.8339, Train Acc: 87.68%, Test Loss: 1.4084, Test Acc: 67.83%
# Epoch [46/50], LR: 0.00006287, Train Loss: 0.7978, Train Acc: 87.10%, Test Loss: 1.4311, Test Acc: 69.23%
# Epoch [47/50], LR: 0.00003586, Train Loss: 0.8213, Train Acc: 87.10%, Test Loss: 1.4474, Test Acc: 69.93%
# Epoch [48/50], LR: 0.00001663, Train Loss: 0.8019, Train Acc: 88.27%, Test Loss: 1.4366, Test Acc: 70.63%
# Epoch [49/50], LR: 0.00000532, Train Loss: 0.8129, Train Acc: 87.10%, Test Loss: 1.4342, Test Acc: 69.93%
# Epoch [50/50], LR: 0.00000203, Train Loss: 0.7871, Train Acc: 89.44%, Test Loss: 1.4417, Test Acc: 69.23%
# Training complete. Best Model Saved.

# %%
y_pred = []
y_true = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        y_pred.extend(predicted.cpu().numpy())
        y_true.extend(labels.cpu().numpy())

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Anger', 'Fear', 'Happy', 'Neutral', 'Sadness', 'Surprise'], yticklabels=['Anger', 'Fear', 'Happy', 'Neutral', 'Sadness', 'Surprise'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
# Plot Accuracy and Loss
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(train_acc_list, label='Train Accuracy')
plt.plot(test_acc_list, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy per Epoch')

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(train_loss_list, label='Train Loss')
plt.plot(test_loss_list, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss per Epoch')

plt.tight_layout()
plt.show()

# %%
# Define a function to predict the emotion
def predict_expression(image, model, device):
    # Detect the face in the image
    face = detect_face(image)
    if face is None:
        return None, None  # No face detected

    # Apply necessary transforms
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    face_tensor = transform(face).unsqueeze(0).to(device)

    # Predict the emotion using the model
    model.eval()
    with torch.no_grad():
        outputs = model(face_tensor)
        _, predicted = torch.max(outputs, 1)

    # Convert predicted label to the corresponding emotion
    emotion = train_dataset.classes[predicted.item()]
    return emotion, face

# Define function to draw bounding box and emotion text for multiple faces
def draw_faces_and_predictions(image, model, device):
    # Convert image to grayscale for face detection
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(faces) == 0:
        print("No faces detected.")
        return image

    # Loop over all detected faces
    for (x, y, w, h) in faces:
        # Extract the face region from the image
        face = image[y:y+h, x:x+w]

        # Predict the expression of the face
        emotion, _ = predict_expression(face, model, device)
        if emotion is None:
            continue  # If no face is detected, skip

        # Draw the bounding box and the emotion label on the image
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(image, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    return image

# Test the model with a single image (handling multiple faces)
def test_single_image_multiple_faces(image_path, model, face_cascade, device):
    # Read the image
    image = cv2.imread(image_path)
    image_copy = image.copy()

    # Detect faces and predict emotions
    image_with_predictions = draw_faces_and_predictions(image_copy, model, device)

    # Plot images: Original, Image with bounding boxes, and Image with predictions
    plt.figure(figsize=(18, 6))

    # 1st Image - Original Image
    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    # 2nd Image - Image with bounding boxes and predictions
    plt.subplot(1, 3, 2)
    plt.imshow(cv2.cvtColor(image_with_predictions, cv2.COLOR_BGR2RGB))
    plt.title('Expression detection')
    plt.axis('off')

    # 3rd Image - Image with predicted emotions (showing a close-up of one of the faces)
    # Choose one face to show the close-up of (just for demonstration purposes)
    # if len(faces) > 0:
    #     x, y, w, h = faces[0]  # Just show the first detected face
    #     face = image[y:y+h, x:x+w]
    #     plt.subplot(1, 3, 3)
    #     plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))
    #     plt.title(f'Predicted Emotion: {emotion}')
    #     plt.axis('off')
    # else:
    plt.subplot(1, 2, 2)
    # plt.text(0.5, 0.5, 'No faces detected in the image', ha='center', va='center', fontsize=12)
    plt.axis('off')
    

    plt.tight_layout()
    plt.show()


#img_path = 'datasets/1/test/neutral/PrivateTest_698548.jpg'
img_path = 'CK_dataset/train/neutral/120.jpg'

test_single_image_multiple_faces(img_path, model, face_cascade, device)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7280\2690880092.py:92: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %%
# Generate Classification Report
report = classification_report(y_true, y_pred, target_names=test_dataset.classes)
print("Classification Report:\n", report)

# Other metrics: Precision, Recall, F1-Score for the entire dataset
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Precision: {precision * 100:.4f}")
print(f"Recall: {recall * 100:.4f}")
print(f"F1 Score: {f1 * 100:.4f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.80      0.44      0.57        18
#         fear       0.25      0.14      0.18         7
#        happy       1.00      0.83      0.91        30
#      neutral       0.54      0.78      0.64        36
#      sadness       0.52      0.65      0.58        17
#     surprise       0.84      0.74      0.79        35
#
#     accuracy                           0.69       143
#    macro avg       0.66      0.60      0.61       143
# weighted avg       0.73      0.69      0.69       143
#
# Precision: 72.5834
# Recall: 69.2308
# F1 Score: 69.3413

# %%
# Define dataset paths
train_dir = "1/train"
test_dir = "1/test"

# Data Preprocessing: Convert grayscale to RGB for ResNet18
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),  # Convert grayscale to 3-channel RGB
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Standard ResNet normalisation
])

# Load FER-2013 dataset using ImageFolder
train_dataset = ImageFolder(train_dir, transform=transform)
test_dataset = ImageFolder(test_dir, transform=transform)

# DataLoader setup
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ResNet18 with pretrained weights
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# Modify the classifier for 6 emotion classes
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 6)
nn.init.kaiming_normal_(model.fc.weight)  # He initialization for stability

# Move model to device
model.to(device)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)  # AdamW with weight decay

# Learning rate scheduler: OneCycleLR (fast convergence)
scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=2e-3,  # Peak learning rate
    total_steps=10 * len(train_loader),  # 10 epochs total steps
    pct_start=0.3,
    anneal_strategy="cos",
    div_factor=10,
    final_div_factor=100
)

# Backup scheduler: ReduceLROnPlateau (if using)
plateau_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    patience=3,
    factor=0.5,
    min_lr=1e-6
)

# Enable mixed precision training (if CUDA is available)
scaler = torch.cuda.amp.GradScaler() if torch.cuda.is_available() else None

print("Model loaded and ready on:", device)

# Training setup
num_epochs = 10
train_acc_list, test_acc_list = [], []
train_loss_list, test_loss_list = [], []

best_test_acc = 0.0  # Track best accuracy for model saving

for epoch in range(num_epochs):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        if scaler:  # Mixed precision training
            with torch.cuda.amp.autocast():
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()

            # Unscale gradients before clipping
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            scaler.step(optimizer)
            scaler.update()
        else:  # Standard training (CPU)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
            optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

        # Step OneCycleLR per batch
        if isinstance(scheduler, torch.optim.lr_scheduler.OneCycleLR):
            scheduler.step()

    train_accuracy = 100 * correct / total
    train_acc_list.append(train_accuracy)
    train_loss_list.append(running_loss / len(train_loader))

    # %% Evaluation Phase
    model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            with torch.cuda.amp.autocast():
                outputs = model(images)
                loss = criterion(outputs, labels)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_accuracy = 100 * correct_test / total_test
    test_acc_list.append(test_accuracy)
    test_loss_list.append(test_loss / len(test_loader))

    # Reduce learning rate with ReduceLROnPlateau (if applicable)
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(test_loss_list[-1])

    # Save best model based on test accuracy
    if test_accuracy > best_test_acc:
        best_test_acc = test_accuracy
        torch.save(model.state_dict(), "best_emotion_recognition_model.pth")

    # Logging results for this epoch
    print(f"Epoch [{epoch + 1}/{num_epochs}], LR: {optimizer.param_groups[0]['lr']:.8f}, "
          f"Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_accuracy:.2f}%, "
          f"Test Loss: {test_loss_list[-1]:.4f}, Test Acc: {test_accuracy:.2f}%")

print("Training complete. Best model saved.")
# Out:
# Model loaded and ready on: cpu
# C:\Users\danie\anaconda3\envs\untitled\lib\site-packages\torch\amp\autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Epoch [1/10], LR: 0.00065031, Train Loss: 1.1891, Train Acc: 54.72%, Test Loss: 1.1932, Test Acc: 54.92%
# Epoch [2/10], LR: 0.00155062, Train Loss: 1.1147, Train Acc: 57.25%, Test Loss: 1.1361, Test Acc: 55.99%
# Epoch [3/10], LR: 0.00200000, Train Loss: 1.0765, Train Acc: 59.52%, Test Loss: 1.0528, Test Acc: 59.84%
# Epoch [4/10], LR: 0.00190085, Train Loss: 0.9765, Train Acc: 63.28%, Test Loss: 1.0611, Test Acc: 59.81%
# Epoch [5/10], LR: 0.00162347, Train Loss: 0.8417, Train Acc: 68.70%, Test Loss: 1.0209, Test Acc: 62.59%
# Epoch [6/10], LR: 0.00122280, Train Loss: 0.6425, Train Acc: 76.51%, Test Loss: 1.0107, Test Acc: 65.25%
# Epoch [7/10], LR: 0.00077821, Train Loss: 0.3309, Train Acc: 88.12%, Test Loss: 1.3192, Test Acc: 65.76%
# Epoch [8/10], LR: 0.00037774, Train Loss: 0.1029, Train Acc: 96.66%, Test Loss: 1.8583, Test Acc: 66.48%
# Epoch [9/10], LR: 0.00010071, Train Loss: 0.0307, Train Acc: 99.17%, Test Loss: 2.1314, Test Acc: 66.62%
# Epoch [10/10], LR: 0.00000200, Train Loss: 0.0117, Train Acc: 99.64%, Test Loss: 2.2506, Test Acc: 66.55%
# Training complete. Best model saved.

# %%
import random
import torch
from torchvision.transforms import ToPILImage
import matplotlib.pyplot as plt

# Convert tensor to PIL image for visualization
to_pil = ToPILImage()

# Select 3 random images from the test dataset
random_indices = random.sample(range(len(test_dataset)), 3)

# Set model to evaluation mode
model.eval()

# Create a figure to display images
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, idx in enumerate(random_indices):
    # Load image and label
    image, true_label = test_dataset[idx]
    image_tensor = image.unsqueeze(0).to(device)  # Add batch dimension

    # Get model prediction
    with torch.no_grad():
        output = model(image_tensor)
        predicted_label = torch.argmax(output, dim=1).item()

    # Convert image tensor to PIL image for display
    image_pil = to_pil(image)

    # Display image with labels
    axes[i].imshow(image_pil)
    axes[i].set_title(f"True: {test_dataset.classes[true_label]}\nPredicted: {test_dataset.classes[predicted_label]}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()
